# %% [markdown]
# <a href="https://colab.research.google.com/github/kittimaxz/data_viz_2022/blob/main/DataViz01_Table_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df['Name'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# # Parallel Coordinates

# %%
pd.plotting.parallel_coordinates(df,'Name') # Sort ตารางค่าแต่ละ Corlumn เทียบค่ากัน โดยใช้ parallel coordinates # โดยกำหนดค่าเป็น (ชื่อตัวแปรข้อมูลที่ต้องการดู,ชื่อ column ที่ต้องการ)

# %% [markdown]
# ### select cor

# %%
pd.plotting.parallel_coordinates(df,'Name',cols = ['SepalLength','PetalLength']);

# %% [markdown]
# ### change color

# %%
pd.plotting.parallel_coordinates(df,'Name',color = ['r','y','k']) # ใช้สีจากค่าสีที่มีอยู่แล้วทั่วไป

# %%
pd.plotting.parallel_coordinates(df,'Name',color = [[0.5,0.5,0.5],[0,0,0.8],[0.2,0.4,0.7]]) # ใช้การผสมสีเอง จากค่าสีที่ต้องการ

# %%
pd.plotting.parallel_coordinates(df,'Name',color = ['#FF00E0','#00FFE2','#ECFF00']) # การใช้ค่าสี โดยการใช้ code สี

# %% [markdown]
# ### Specify color by colormap

# %%
pd.plotting.parallel_coordinates(df,'Name',colormap = 'Set1') # การเลือกใช้สีตาม colormap โดยที่ถ้ามีข้อมูล 3 ชนิดก็จะสุ่มสีโดยการสุ่ม หัว,กลาง,ท้าย ของ colormap

# %% [markdown]
# ## Matplotlib

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib

# %% [markdown]
# ## Heatmap matrix

# %%
matplotlib.rcParams['figure.figsize']=[25,25] # กำหนดขนาด figure
plt.imshow(df.iloc[:,:-1],interpolation='nearest') # ยิ่งสีเข้มข้อมูลยิ่งน้อย ยิ่งสีสว่างข้อมูลยิ่งมาก

# %%
plt.imshow(df.iloc[:,:-1],interpolation='nearest',cmap='hot') # ยิ่งสีเข้มข้อมูลยิ่งน้อย ยิ่งสีสว่างข้อมูลยิ่งมาก

# %% [markdown]
# ### Subplot

# %%
pd.plotting.parallel_coordinates(df,'Name',color = [[0.5,0.5,0.5,0.5],[0,0,0.8,0.5],[0.2,0.4,0.7,0.5]])
